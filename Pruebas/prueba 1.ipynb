# %% [markdown]
# # First Notebook

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.1

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.4.2
